# %%
from awpy.parser import DemoParser

import os
#My GO was installed somewhere weird, so I need to specify the path
os.environ['PATH'] += os.pathsep + '/usr/local/go/bin'

demo_path = "natus-vincere-vs-liquid-m2-dust2.dem"
demo_parser = DemoParser(demofile=demo_path, parse_rate=1)
parsed_data = demo_parser.parse()

# %%
from awpy.data import NAV

def getCallout(coordinates):
    map=NAV["de_dust2"]
    for num, row in map.items():
        if row['northWestX'] <= coordinates[0] <= row['southEastX'] and row['northWestY'] <= coordinates[1] <= row['southEastY']:
            return row['areaName']
    return "Failed"

# %%
def get_players(parsed_data,roundnum, tick, side):
    team_stats = {} #includes both dead and living players
    round_data = parsed_data["gameRounds"][roundnum-1]
    alive=0
    teamEqVal=0
    if side=="ctSide":
        frameSide="ct"
        killSide="CT"
    else:
        frameSide="t"
        killSide="T"
    # last_tick=0

    for player in round_data[side]["players"]:
        team_stats[player["steamID"]] = {
            "playerName": player["playerName"],
            "is_alive": True, #F
            "hp": 100, #F
            "armor": 0, #F
            "equipment_value": 0, #F
            "cash_spend_this_round":0, #F
            "primary_weapon": None, #F   #needs to look the data structure closer
            "secondary_weapon": None, #F  #needs to look the data structure closer
            "active_weapon_category": None, #F    #Active Weapon Category of Player (One of either Primary, Secondary, Knife),
            "grenades_left": 0, #F     #(int) Number of grenades held by player,
            "flashes_left": 0,   #F    #(int) Number of flashes held by player,
            "smokes_left": 0,    #F    #(int) Number of smokes held by player,
            "molotovs_left": 0,  #F    #(int) Number of molotovs held by player,
            "is_blinded": False, #F    #[BONUS] (bool) Whether the player is blinded,
            "is_ducking": False, #F    #[BONUS] (bool)  Whether the player is ducking,
            "is_scoped": False,  #F    #[BONUS] (bool) Whether the player is scoped,
            "cash": 0,           #F    #(int) Amount of cash player has,
            "has_helmet": False, #F    #(bool) Whether the player has a helmet, DELETE!!!
            "has_defuser": False, #F   # (bool) Whether the player has a defuser,
            "total_kills": None,       #F
            "round_kills": 0,    #F
            "round_deaths": 0,   #F
            "total_deaths": None,      #F
            "lastKnownWeapon": None,        #F
            "lastKnownPosition": None,      #F
            "velocityX": None,          #The velocity at X direction
            "velocityY": None,          #The velocity at Y direction
            "velocityZ": None,          #The velocity at Z direction
            "viewX": None,              #The X direction of the player
            "viewY": None,              #The Y direction of the player
            "callout": None,
            "average_damage_per_round": 0, #[SUPER SUPER BONUS] (int) Average amount of damage output from a player across all previous rounds,
            "survives_round": False, #F    #(bool) Whether the player survives the round,
            "time_of_death": 0, #time in ticks until player's death
            #Additional for dead players
            "person_killed_by": None, #F     #(string) name of player who killed this dead_player,
            "weapon_killed_by": None, #F     #(string) name of weapon that dealt final blow to player (should be active weapon of person_killed_by),
            "amount_spent": 0,     #F    # used cashSpendTotal(the whole game)
            "round_damage": 0

        }

    for event in round_data["kills"]:
        if event["tick"] <= tick and event["attackerSide"] == killSide:
            team_stats[event["attackerSteamID"]]["round_kills"] += 1
            # if event["isHeadshot"]:
            #     ct_stats[event["attackerSteamID"]]["headshots"] += 1

        if event["tick"] <= tick and event["victimSide"] == killSide:
            team_stats[event["victimSteamID"]]["round_deaths"] += 1
            team_stats[event["victimSteamID"]]["time_of_death"] = event["tick"]
            team_stats[event["victimSteamID"]]["person_killed_by"] = event["attackerName"]
            team_stats[event["victimSteamID"]]["weapon_killed_by"] = event["weapon"]

    for event in round_data["damages"]:
        if event["tick"] <= tick and event["attackerSide"] == killSide:
            team_stats[event["attackerSteamID"]]["round_damage"] += event["hpDamageTaken"]

    for frame in round_data["frames"]:
        # print(frame["tick"], tick)
        if frame["tick"] <= tick:
            # print(f'frame: {frame["tick"]} tick: {tick}')
            # print("clocktime"+frame["clockTime"])
            # last_tick=frame["tick"]  #checking for if they actually match
            teamEqVal=frame[frameSide]["teamEqVal"]
            for player in frame[frameSide]["players"]:
                if player["steamID"] in team_stats:
                    team_stats[player["steamID"]]["lastKnownPosition"] = [player["x"],player["y"],player["z"]]
                    team_stats[player["steamID"]]["callout"] = getCallout([player["x"],player["y"],player["z"]])
                    team_stats[player["steamID"]]["lastKnownWeapon"] = [player["inventory"]][0]
                    team_stats[player["steamID"]]["hp"] = [player["hp"]][0]
                    team_stats[player["steamID"]]["is_alive"] = [player["isAlive"]][0]
                    team_stats[player["steamID"]]["survives_round"] = [player["isAlive"]][0]
                    team_stats[player["steamID"]]["armor"] = [player["armor"]][0]
                    team_stats[player["steamID"]]["equipment_value"] = [player["equipmentValue"]][0]
                    team_stats[player["steamID"]]["cash_spend_this_round"] = [player["cashSpendThisRound"]][0]
                    team_stats[player["steamID"]]["is_blinded"] = [player["isBlinded"]][0]
                    team_stats[player["steamID"]]["is_ducking"] = [player["isDucking"]][0]
                    team_stats[player["steamID"]]["is_scoped"] = [player["isScoped"]][0]
                    team_stats[player["steamID"]]["cash"] = [player["cash"]][0]
                    team_stats[player["steamID"]]["has_helmet"] = [player["hasHelmet"]][0]
                    team_stats[player["steamID"]]["has_defuser"] = [player["hasDefuse"]][0]
                    team_stats[player["steamID"]]["amount_spent"] = [player["cashSpendTotal"]][0]
                    team_stats[player["steamID"]]["active_weapon_category"] = [player["activeWeapon"]][0]
                    team_stats[player["steamID"]]["velocityX"] = [player["velocityX"]][0]
                    team_stats[player["steamID"]]["velocityY"] = [player["velocityY"]][0]
                    team_stats[player["steamID"]]["velocityZ"] = [player["velocityZ"]][0]
                    team_stats[player["steamID"]]["viewX"] = [player["viewX"]][0]
                    team_stats[player["steamID"]]["viewY"] = [player["viewY"]][0]
                    
                if player["isAlive"] and frame["tick"] == tick:
                    # print("aaa")
                    alive+=1
        else:
            #break the loop once the tick exceeds the specified tick
            break
    # print(f'frame: {last_tick} tick: {tick}')
    extraData={}
    extraData["team"]=team_stats
    living_players={}
    dead_players={}
    keys_toRemove=["person_killed_by", "weapon_killed_by", "amount_spent","lastKnownWeapon"]
    keys_toKeep={"playerName", "person_killed_by", "weapon_killed_by","lastKnownPosition", "callout",
                "cash", "amount_spent", "equipment_value", "cash_spend_this_round", 
                "round_kills", "round_deaths", "time_of_death", "round_damage"}

    for id, stat_item in team_stats.items():
        if stat_item["is_alive"]:
            # print(stat_item["lastKnownWeapon"])
            for weapon in stat_item["lastKnownWeapon"]:
                # print(weapon["weaponClass"])
                if weapon["weaponClass"]=="Pistols":
                    stat_item["secondary_weapon"]=weapon["weaponName"]
                if weapon["weaponClass"]=="Rifle":
                    stat_item["primary_weapon"]=weapon["weaponName"]
                if weapon["weaponClass"]=="SMG":
                    stat_item["primary_weapon"]=weapon["weaponName"]
                if weapon["weaponName"]=="HE Grenade":
                    stat_item["grenades_left"]=weapon["ammoInMagazine"]+weapon["ammoInReserve"]
                if weapon["weaponName"]=="Flashbang":
                    stat_item["flashes_left"]=weapon["ammoInMagazine"]+weapon["ammoInReserve"]
                if weapon["weaponName"]=="Smoke Grenade":
                    stat_item["smokes_left"]=weapon["ammoInMagazine"]+weapon["ammoInReserve"]
                if weapon["weaponName"]=="Molotov": ### !!! Needs to be tested to find the exact matching name
                    stat_item["molotovs_left"]=weapon["ammoInMagazine"]+weapon["ammoInReserve"]
            if stat_item["active_weapon_category"]==stat_item["primary_weapon"]:
                stat_item["active_weapon_category"]="Primary"
            elif stat_item["active_weapon_category"]==stat_item["secondary_weapon"]:
                stat_item["active_weapon_category"]="Secondary"
            else:
                stat_item["active_weapon_category"]="Knife"
                
            for key in keys_toRemove:
                if key in stat_item:
                    del stat_item[key]
            living_players[id]=stat_item
        else:
            for key in list(stat_item.keys()):
                if key not in keys_toKeep:
                    del stat_item[key]
            dead_players[id]=stat_item
    
    
    extraData["team_equipment_value"] = teamEqVal
    return living_players, dead_players, extraData

# living_players, dead_players, extra=get_players(parsed_data,1, 16614, "tSide")

# print("living")
# for steamID, stats in living_players.items():
#     print("")
#     for para, stat in stats.items():
#         print(f'{para}: {stat}')
# print("dead")
# for steamID, stats in dead_players.items():
#     print("")
#     for para, stat in stats.items():
#         print(f'\t{para}: {stat}')

# for para, stat in extra.items():
#     print("")
#     print(f'\t{para}: {stat}')

# %%
import json

def rounds_stats(demo_data):
    bomb_rounds=[]
    rounds_stats={}
    bombPosition=[]
    for round in demo_data["gameRounds"]:
        # print(round["roundNum"])
        for bomb_event in round["bombEvents"]:
            if bomb_event["bombAction"]=="plant":
                bomb_rounds.append(round["roundNum"])
                bombPosition=[bomb_event['playerX'],bomb_event['playerY'],bomb_event['playerZ']]
        # print(round["roundNum"],round["endOfficialTick"])
        living_players, dead_players, extraData=get_players(demo_data,round["roundNum"], round["endTick"],"ctSide")  #The difference I found is that the officialend tick would clear cash spend this round
        living_players1, dead_players1, extraData1=get_players(demo_data,round["roundNum"], round["endTick"],"tSide")
        round_stat={
            "round_winner": round["winningSide"], #F   #(string) Team that wins the round ("CT_Team" or "T_Team"),
            "round_number": round["roundNum"], #F   #(int) Number of current round,
            "bomb_coordinates": bombPosition,     #F  not very sure whether to use bombposition in frames.
            "round_length": round["endOfficialTick"]-round["startTick"], #BONUS]
            "bomb_plant_time": round["bombPlantTick"], #[BONUS] 
            "ct_team": {
                "rounds_won": 0, #F  Should I include current round?
                "team_equipment_value": extraData["team_equipment_value"], #DO this while also check if bombpositions are the same from frames and bombevents
                "living_players": living_players,
                "dead_players": dead_players
            },
            "t_team":{
                "rounds_won": 0,#(int) Number of rounds team has already won,
                "team_equipment_value": extraData1["team_equipment_value"],#(int) See teamEqVal in frames,
                "living_players": living_players1,
                "dead_players": dead_players1
            },
            "winningSide": round["winningSide"]
        }
        rounds_stats[round["roundNum"]]=round_stat
    
    tWins=0
    ctWins=0
    totalKill={}
    totalDeath={}
    totalDamage={}
    totalRound=0
    avgDamage={}
    
    for id, value in extraData["team"].items():
        totalKill[id]=0
        totalDeath[id]=0
        totalDamage[id]=0
    for id, value in extraData1["team"].items():
        totalKill[id]=0
        totalDeath[id]=0
        totalDamage[id]=0
    for roundNum, round in rounds_stats.items():
        for ID, player in round["ct_team"]["living_players"].items():
            totalKill[ID]+=player["round_kills"]
            totalDeath[ID]+=player["round_deaths"]
            totalDamage[ID]+=player["round_damage"]
            
        for ID, player in round["ct_team"]["dead_players"].items():
            totalKill[ID]+=player["round_kills"]
            totalDeath[ID]+=player["round_deaths"]
            totalDamage[ID]+=player["round_damage"]
        for ID, player in round["t_team"]["living_players"].items():
            totalKill[ID]+=player["round_kills"]
            totalDeath[ID]+=player["round_deaths"]
            totalDamage[ID]+=player["round_damage"]
            
        for ID, player in round["t_team"]["dead_players"].items():
            totalKill[ID]+=player["round_kills"]
            totalDeath[ID]+=player["round_deaths"]
            totalDamage[ID]+=player["round_damage"]
        rounds_stats[roundNum]["ct_team"]["rounds_won"]=ctWins
        rounds_stats[roundNum]["t_team"]["rounds_won"]=tWins
        if round["winningSide"]=="T":
            tWins+=1
        if round["winningSide"]=="CT":
            ctWins+=1
        totalRound=roundNum
    
    for roundNum, round in rounds_stats.items():
        # print(roundNum)
        for ID, player in round["ct_team"]["living_players"].items():
            rounds_stats[roundNum]["ct_team"]["living_players"][ID]["total_kills"]=totalKill[ID]
            rounds_stats[roundNum]["ct_team"]["living_players"][ID]["total_deaths"]=totalDeath[ID]
            # rounds_stats[roundNum]["ct_team"]["living_players"][ID]["total_damage"]=totalDamage[ID]
            rounds_stats[roundNum]["ct_team"]["living_players"][ID]["average_damage_per_round"]=totalDamage[ID]/totalRound
            avgDamage[ID]=totalDamage[ID]/totalRound
            # del rounds_stats[roundNum]["ct_team"]["living_players"][ID]["total_damage"]
        for ID, player in round["t_team"]["living_players"].items():
            rounds_stats[roundNum]["t_team"]["living_players"][ID]["average_damage_per_round"]=totalDamage[ID]/totalRound
            rounds_stats[roundNum]["t_team"]["living_players"][ID]["total_kills"]=totalKill[ID]
            rounds_stats[roundNum]["t_team"]["living_players"][ID]["total_deaths"]=totalDeath[ID]
            # rounds_stats[roundNum]["t_team"]["living_players"][ID]["total_damage"]=totalDamage[ID]
            avgDamage[ID]=totalDamage[ID]/totalRound
            # del rounds_stats[roundNum]["t_team"]["living_players"][ID]["total_damage"]

        # To get rid of the round number key
        statHolder=[]
        for id, stat in rounds_stats[roundNum]["ct_team"]["living_players"].items():
            statHolder.append(stat)
        rounds_stats[roundNum]["ct_team"]["living_players"]=statHolder
        statHolder=[]
        for id, stat in rounds_stats[roundNum]["ct_team"]["dead_players"].items():
            statHolder.append(stat)
        rounds_stats[roundNum]["ct_team"]["dead_players"]=statHolder
        statHolder=[]
        for id, stat in rounds_stats[roundNum]["t_team"]["living_players"].items():
            statHolder.append(stat)
        rounds_stats[roundNum]["t_team"]["living_players"]=statHolder
        statHolder=[]
        for id, stat in rounds_stats[roundNum]["t_team"]["dead_players"].items():
            statHolder.append(stat)
        rounds_stats[roundNum]["t_team"]["dead_players"]=statHolder
    # print(totalRound)
    # print(list(rounds_stats.keys()))
    total=[totalDeath, totalKill, avgDamage]
    for key in list(rounds_stats.keys()):
        if key not in bomb_rounds:
            del rounds_stats[key]

    # for key, item in rounds_stats[5].items():
    #     print(f'{key}: {item}')
    
    json_stats = json.dumps(rounds_stats)
    return json_stats, rounds_stats, total
    # for key, round in rounds_stats.items():
    #     print(f'roundNum: {key} ct: {round["ct_team"]["rounds_won"]} \t t: {round["t_team"]["rounds_won"]}')

    # print(list(rounds_stats.keys()))
jsonStat,stat, total=rounds_stats(parsed_data)

# %%
for roundNum, value in stat.items():
    print(f"round:{roundNum}")
    for key,stats in value.items():
        if key=="ct_team" or key=="t_team":
            print("\t"+key)
            for para, playerStat in stats.items():
                if para=="living_players" or para=="dead_players":
                    print("\t\t"+para+":")
                    # print(playerStat)
                    for player in playerStat:
                        for playerPara, player_stat in player.items():
                            line=str(playerPara)+": "+str(player_stat)
                            print("\t\t\t"+line)
                        print("")
                else:
                    line=str(para)+": "+str(playerStat)
                    print("\t\t"+line)
        else:
            line=str(key)+": "+str(stats)
            print("\t"+line)
# Out:
# round:1
# 	round_winner: T
# 	round_number: 1
# 	bomb_coordinates: [1235.9864501953125, 2560.01708984375, 99.3785400390625]
# 	round_length: 15439
# 	bomb_plant_time: 14671
# 	ct_team
# 		rounds_won: 0
# 		team_equipment_value: 4800
# 		living_players:
# 		dead_players:
# 			playerName: Grim
# 			equipment_value: 850
# 			cash_spend_this_round: 650
# 			cash: 2050
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [349.9615478515625, 1978.8067626953125, 96.05490112304688]
# 			callout: ExtendedA
# 			time_of_death: 15566
# 			person_killed_by: Boombl4
# 			weapon_killed_by: Glock-18
# 			amount_spent: 650
# 			round_damage: 137
#
# 			playerName: NAF
# 			equipment_value: 850
# 			cash_spend_this_round: 650
# 			cash: 2350
# 			round_kills: 1
# 			round_deaths: 1
# 			lastKnownPosition: [967.9830322265625, 2254.37451171875, 8.467218399047852]
# 			callout: UnderA
# 			time_of_death: 15824
# 			person_killed_by: electronic
# 			weapon_killed_by: Glock-18
# 			amount_spent: 650
# 			round_damage: 100
#
# 			playerName: FalleN
# 			equipment_value: 1000
# 			cash_spend_this_round: 800
# 			cash: 1900
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [-1136.9005126953125, 1116.1732177734375, -19.6876220703125]
# 			callout: TunnelStairs
# 			time_of_death: 8770
# 			person_killed_by: Stewie2K
# 			weapon_killed_by: USP-S
# 			amount_spent: 800
# 			round_damage: 19
#
# 			playerName: EliGE
# 			equipment_value: 850
# 			cash_spend_this_round: 650
# 			cash: 2050
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [-211.20872497558594, 618.892578125, 1.2774314880371094]
# 			callout: TopofMid
# 			time_of_death: 5780
# 			person_killed_by: s1mple
# 			weapon_killed_by: P250
# 			amount_spent: 650
# 			round_damage: 0
#
# 			playerName: Stewie2K
# 			equipment_value: 1250
# 			cash_spend_this_round: 950
# 			cash: 2200
# 			round_kills: 2
# 			round_deaths: 1
# 			lastKnownPosition: [383.3780822753906, 1890.9866943359375, 95.6199951171875]
# 			callout: ShortStairs
# 			time_of_death: 15973
# 			person_killed_by: b1t
# 			weapon_killed_by: Glock-18
# 			amount_spent: 950
# 			round_damage: 83
#
# 	t_team
# 		rounds_won: 0
# 		team_equipment_value: 3950
# 		living_players:
# 			playerName: electronic
# 			is_alive: True
# 			hp: 63
# 			armor: 100
# 			equipment_value: 850
# 			cash_spend_this_round: 650
# 			primary_weapon: None
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Secondary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 3700
# 			has_helmet: False
# 			has_defuser: False
# 			total_kills: 16
# 			round_kills: 1
# 			round_deaths: 0
# 			total_deaths: 13
# 			headshot_percentage: 0
# 			lastKnownPosition: [980.7254028320312, 2412.095947265625, 127.03125]
# 			velocityX: -215.4219207763672
# 			velocityY: 4.962827682495117
# 			velocityZ: 0
# 			viewX: 217.8643798828125
# 			viewY: 2.8509521484375
# 			callout: BombsiteA
# 			average_damage_per_round: 75.69565217391305
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 81
#
# 			playerName: b1t
# 			is_alive: True
# 			hp: 72
# 			armor: 0
# 			equipment_value: 900
# 			cash_spend_this_round: 700
# 			primary_weapon: None
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Secondary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: True
# 			is_scoped: False
# 			cash: 3650
# 			has_helmet: False
# 			has_defuser: False
# 			total_kills: 19
# 			round_kills: 1
# 			round_deaths: 0
# 			total_deaths: 9
# 			headshot_percentage: 0
# 			lastKnownPosition: [1109.8370361328125, 2892.85205078125, 127.788330078125]
# 			velocityX: -55.501686096191406
# 			velocityY: 40.242095947265625
# 			velocityZ: 0
# 			viewX: 234.437255859375
# 			viewY: 0.648193359375
# 			callout: BombsiteA
# 			average_damage_per_round: 83.56521739130434
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 151
#
# 			playerName: Boombl4
# 			is_alive: True
# 			hp: 28
# 			armor: 0
# 			equipment_value: 400
# 			cash_spend_this_round: 800
# 			primary_weapon: None
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Secondary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 3850
# 			has_helmet: False
# 			has_defuser: False
# 			total_kills: 17
# 			round_kills: 1
# 			round_deaths: 0
# 			total_deaths: 9
# 			headshot_percentage: 0
# 			lastKnownPosition: [1194.033447265625, 2645.463623046875, 96.12249755859375]
# 			velocityX: -139.8811798095703
# 			velocityY: 170.53988647460938
# 			velocityZ: 0
# 			viewX: 220.902099609375
# 			viewY: 0
# 			callout: BombsiteA
# 			average_damage_per_round: 68.8695652173913
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 37
#
# 		dead_players:
# 			playerName: Perfecto
# 			equipment_value: 850
# 			cash_spend_this_round: 650
# 			cash: 3400
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [-1218.9442138671875, 1046.100341796875, 17.975534439086914]
# 			callout: TunnelStairs
# 			time_of_death: 8792
# 			person_killed_by: Stewie2K
# 			weapon_killed_by: USP-S
# 			amount_spent: 650
# 			round_damage: 110
#
# 			playerName: s1mple
# 			equipment_value: 950
# 			cash_spend_this_round: 650
# 			cash: 3700
# 			round_kills: 1
# 			round_deaths: 1
# 			lastKnownPosition: [1394.60986328125, 1870.052490234375, -8.194436073303223]
# 			callout: LongA
# 			time_of_death: 15649
# 			person_killed_by: NAF
# 			weapon_killed_by: USP-S
# 			amount_spent: 650
# 			round_damage: 119
#
# 	winningSide: T
# round:5
# 	round_winner: T
# 	round_number: 5
# 	bomb_coordinates: [-1530.82373046875, 2580.241455078125, 5.538149833679199]
# 	round_length: 21507
# 	bomb_plant_time: 69921
# 	ct_team
# 		rounds_won: 2
# 		team_equipment_value: 27400
# 		living_players:
# 			playerName: EliGE
# 			is_alive: True
# 			hp: 34
# 			armor: 88
# 			equipment_value: 5600
# 			cash_spend_this_round: 0
# 			primary_weapon: M4A1
# 			secondary_weapon: USP-S
# 			active_weapon_category: Knife
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 1850
# 			has_helmet: True
# 			has_defuser: True
# 			total_kills: 17
# 			round_kills: 1
# 			round_deaths: 0
# 			total_deaths: 18
# 			headshot_percentage: 0
# 			lastKnownPosition: [1292.00048828125, 246.2287139892578, -175.3341827392578]
# 			velocityX: 0
# 			velocityY: 0
# 			velocityZ: 0
# 			viewX: 90.1483154296875
# 			viewY: 358.604736328125
# 			callout: Pit
# 			average_damage_per_round: 92.43478260869566
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 196
#
# 			playerName: Grim
# 			is_alive: True
# 			hp: 100
# 			armor: 100
# 			equipment_value: 5400
# 			cash_spend_this_round: 0
# 			primary_weapon: M4A1
# 			secondary_weapon: USP-S
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 1
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: True
# 			is_scoped: False
# 			cash: 1600
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 6
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 16
# 			headshot_percentage: 0
# 			lastKnownPosition: [1306.8165283203125, 2447.681884765625, 51.9361572265625]
# 			velocityX: -4.784407615661621
# 			velocityY: 0.8502752184867859
# 			velocityZ: 0
# 			viewX: 259.925537109375
# 			viewY: 6.6796875
# 			callout: Failed
# 			average_damage_per_round: 38.130434782608695
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 0
#
# 			playerName: FalleN
# 			is_alive: True
# 			hp: 100
# 			armor: 94
# 			equipment_value: 5000
# 			cash_spend_this_round: 0
# 			primary_weapon: M4A1
# 			secondary_weapon: USP-S
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 1
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 3500
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 8
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 15
# 			headshot_percentage: 0
# 			lastKnownPosition: [1268.0006103515625, 1232.01171875, 0.03125]
# 			velocityX: 0
# 			velocityY: 0
# 			velocityZ: 0
# 			viewX: 219.1717529296875
# 			viewY: 0.626220703125
# 			callout: LongA
# 			average_damage_per_round: 37.47826086956522
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 0
#
# 		dead_players:
# 			playerName: NAF
# 			equipment_value: 5900
# 			cash_spend_this_round: 0
# 			cash: 3700
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [-1194.1630859375, 2663.8251953125, 80.64976501464844]
# 			callout: BDoors
# 			time_of_death: 68459
# 			person_killed_by: b1t
# 			weapon_killed_by: Galil AR
# 			amount_spent: 11100
# 			round_damage: 85
#
# 			playerName: Stewie2K
# 			equipment_value: 5500
# 			cash_spend_this_round: 0
# 			cash: 4500
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [-573.8287353515625, 2134.723876953125, -119.4537582397461]
# 			callout: MidDoors
# 			time_of_death: 67284
# 			person_killed_by: electronic
# 			weapon_killed_by: AK-47
# 			amount_spent: 9250
# 			round_damage: 19
#
# 	t_team
# 		rounds_won: 2
# 		team_equipment_value: 19900
# 		living_players:
# 			playerName: s1mple
# 			is_alive: True
# 			hp: 34
# 			armor: 100
# 			equipment_value: 4100
# 			cash_spend_this_round: 0
# 			primary_weapon: M4A1
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Knife
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 3900
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 14
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 13
# 			headshot_percentage: 0
# 			lastKnownPosition: [-1424.8101806640625, 72.19094848632812, 69.03125]
# 			velocityX: -3.061922311782837
# 			velocityY: -15.442330360412598
# 			velocityZ: 0
# 			viewX: 258.8818359375
# 			viewY: 11.8267822265625
# 			callout: Failed
# 			average_damage_per_round: 84.91304347826087
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 0
#
# 			playerName: electronic
# 			is_alive: True
# 			hp: 68
# 			armor: 97
# 			equipment_value: 4200
# 			cash_spend_this_round: 0
# 			primary_weapon: AK-47
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 3800
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 16
# 			round_kills: 1
# 			round_deaths: 0
# 			total_deaths: 13
# 			headshot_percentage: 0
# 			lastKnownPosition: [-1804.2877197265625, 92.07685089111328, 2.2189865112304688]
# 			velocityX: 88.18281555175781
# 			velocityY: -105.58963775634766
# 			velocityZ: 0
# 			viewX: 77.58544921875
# 			viewY: 358.648681640625
# 			callout: OutsideTunnel
# 			average_damage_per_round: 75.69565217391305
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 78
#
# 			playerName: Perfecto
# 			is_alive: True
# 			hp: 94
# 			armor: 100
# 			equipment_value: 4300
# 			cash_spend_this_round: 0
# 			primary_weapon: AK-47
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Knife
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 3650
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 15
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 10
# 			headshot_percentage: 0
# 			lastKnownPosition: [-991.7149658203125, -559.8663330078125, 192.03125]
# 			velocityX: -24.98759651184082
# 			velocityY: -135.72959899902344
# 			velocityZ: 0
# 			viewX: 349.573974609375
# 			viewY: 10.0360107421875
# 			callout: Failed
# 			average_damage_per_round: 69.47826086956522
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 0
#
# 			playerName: b1t
# 			is_alive: True
# 			hp: 4
# 			armor: 76
# 			equipment_value: 4100
# 			cash_spend_this_round: 0
# 			primary_weapon: M4A1
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Knife
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 3800
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 19
# 			round_kills: 1
# 			round_deaths: 0
# 			total_deaths: 9
# 			headshot_percentage: 0
# 			lastKnownPosition: [-1993.046142578125, -53.6220703125, 25.266098022460938]
# 			velocityX: -9.715635299682617
# 			velocityY: 174.3238067626953
# 			velocityZ: 196.68505859375
# 			viewX: 87.5994873046875
# 			viewY: 12.930908203125
# 			callout: OutsideTunnel
# 			average_damage_per_round: 83.56521739130434
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 122
#
# 		dead_players:
# 			playerName: Boombl4
# 			equipment_value: 3200
# 			cash_spend_this_round: 0
# 			cash: 3700
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [-412.14892578125, 1615.6361083984375, -126.36125183105469]
# 			callout: MidDoors
# 			time_of_death: 69158
# 			person_killed_by: EliGE
# 			weapon_killed_by: M4A1
# 			amount_spent: 11600
# 			round_damage: 66
#
# 	winningSide: T
# round:8
# 	round_winner: T
# 	round_number: 8
# 	bomb_coordinates: [-1692.9576416015625, 2516.3818359375, 9.40342903137207]
# 	round_length: 21618
# 	bomb_plant_time: 122123
# 	ct_team
# 		rounds_won: 4
# 		team_equipment_value: 27250
# 		living_players:
# 			playerName: Stewie2K
# 			is_alive: True
# 			hp: 100
# 			armor: 100
# 			equipment_value: 3950
# 			cash_spend_this_round: 2050
# 			primary_weapon: M4A1
# 			secondary_weapon: USP-S
# 			active_weapon_category: Knife
# 			grenades_left: 0
# 			flashes_left: 1
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 4500
# 			has_helmet: False
# 			has_defuser: False
# 			total_kills: 8
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 17
# 			headshot_percentage: 0
# 			lastKnownPosition: [911.7628173828125, 941.8779296875, 0.2568129003047943]
# 			velocityX: 56.952430725097656
# 			velocityY: 225.34555053710938
# 			velocityZ: 0
# 			viewX: 81.3262939453125
# 			viewY: 6.08642578125
# 			callout: LongDoors
# 			average_damage_per_round: 53.608695652173914
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 31
#
# 			playerName: FalleN
# 			is_alive: True
# 			hp: 30
# 			armor: 84
# 			equipment_value: 7250
# 			cash_spend_this_round: 1400
# 			primary_weapon: AWP
# 			secondary_weapon: USP-S
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 1
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: True
# 			cash: 3400
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 8
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 15
# 			headshot_percentage: 0
# 			lastKnownPosition: [1332.0245361328125, 454.78314208984375, -113.99470520019531]
# 			velocityX: 0
# 			velocityY: 0
# 			velocityZ: 0
# 			viewX: 92.65869140625
# 			viewY: 353.1005859375
# 			callout: Pit
# 			average_damage_per_round: 37.47826086956522
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 0
#
# 			playerName: Grim
# 			is_alive: True
# 			hp: 100
# 			armor: 100
# 			equipment_value: 5800
# 			cash_spend_this_round: 1600
# 			primary_weapon: M4A1
# 			secondary_weapon: USP-S
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 3600
# 			has_helmet: True
# 			has_defuser: True
# 			total_kills: 6
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 16
# 			headshot_percentage: 0
# 			lastKnownPosition: [539.0006103515625, 458.3560791015625, 4.564230442047119]
# 			velocityX: 0
# 			velocityY: 0
# 			velocityZ: 0
# 			viewX: 308.8311767578125
# 			viewY: 1.1865234375
# 			callout: LongDoors
# 			average_damage_per_round: 38.130434782608695
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 0
#
# 		dead_players:
# 			playerName: EliGE
# 			equipment_value: 5600
# 			cash_spend_this_round: 1300
# 			cash: 4950
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [-1632.1019287109375, 1653.2998046875, 2.274974822998047]
# 			callout: BombsiteB
# 			time_of_death: 120548
# 			person_killed_by: b1t
# 			weapon_killed_by: AK-47
# 			amount_spent: 18650
# 			round_damage: 77
#
# 			playerName: NAF
# 			equipment_value: 4650
# 			cash_spend_this_round: 5250
# 			cash: 1400
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [-1402.4520263671875, 2777.8017578125, 17.475419998168945]
# 			callout: BombsiteB
# 			time_of_death: 120697
# 			person_killed_by: Perfecto
# 			weapon_killed_by: AK-47
# 			amount_spent: 23100
# 			round_damage: 0
#
# 	t_team
# 		rounds_won: 3
# 		team_equipment_value: 22650
# 		living_players:
# 			playerName: s1mple
# 			is_alive: True
# 			hp: 100
# 			armor: 100
# 			equipment_value: 5950
# 			cash_spend_this_round: 3700
# 			primary_weapon: AWP
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: True
# 			is_scoped: False
# 			cash: 3900
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 14
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 13
# 			headshot_percentage: 0
# 			lastKnownPosition: [-1812.0274658203125, -495.3794250488281, 137.09307861328125]
# 			velocityX: 0
# 			velocityY: -80.689208984375
# 			velocityZ: 217.61837768554688
# 			viewX: 341.8450927734375
# 			viewY: 4.921875
# 			callout: TRamp
# 			average_damage_per_round: 84.91304347826087
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 70
#
# 			playerName: b1t
# 			is_alive: True
# 			hp: 16
# 			armor: 85
# 			equipment_value: 4300
# 			cash_spend_this_round: 4600
# 			primary_weapon: AK-47
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 1
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 3900
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 19
# 			round_kills: 1
# 			round_deaths: 0
# 			total_deaths: 9
# 			headshot_percentage: 0
# 			lastKnownPosition: [-1791.7623291015625, 990.4385986328125, 40.1737060546875]
# 			velocityX: 0
# 			velocityY: 0
# 			velocityZ: 0
# 			viewX: 13.8043212890625
# 			viewY: 6.712646484375
# 			callout: UpperTunnel
# 			average_damage_per_round: 83.56521739130434
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 100
#
# 			playerName: Boombl4
# 			is_alive: True
# 			hp: 91
# 			armor: 95
# 			equipment_value: 3900
# 			cash_spend_this_round: 3900
# 			primary_weapon: AK-47
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 3600
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 17
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 9
# 			headshot_percentage: 0
# 			lastKnownPosition: [-1792.572021484375, 1034.3436279296875, 39.02902603149414]
# 			velocityX: -55.26648712158203
# 			velocityY: 100.23411560058594
# 			velocityZ: 0
# 			viewX: 5.7403564453125
# 			viewY: 6.822509765625
# 			callout: UpperTunnel
# 			average_damage_per_round: 68.8695652173913
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 0
#
# 			playerName: Perfecto
# 			is_alive: True
# 			hp: 100
# 			armor: 100
# 			equipment_value: 4100
# 			cash_spend_this_round: 4900
# 			primary_weapon: AK-47
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 1
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 4050
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 15
# 			round_kills: 1
# 			round_deaths: 0
# 			total_deaths: 10
# 			headshot_percentage: 0
# 			lastKnownPosition: [-996.406494140625, -633.9876098632812, 169.03125]
# 			velocityX: 0
# 			velocityY: 0
# 			velocityZ: 0
# 			viewX: 296.7626953125
# 			viewY: 16.9683837890625
# 			callout: TSpawn
# 			average_damage_per_round: 69.47826086956522
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 100
#
# 			playerName: electronic
# 			is_alive: True
# 			hp: 69
# 			armor: 89
# 			equipment_value: 4400
# 			cash_spend_this_round: 6450
# 			primary_weapon: AK-47
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 3650
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 16
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 13
# 			headshot_percentage: 0
# 			lastKnownPosition: [-990.0347900390625, -646.7047729492188, 241.0625]
# 			velocityX: -20.34662437438965
# 			velocityY: -20.656925201416016
# 			velocityZ: 0
# 			viewX: 359.3792724609375
# 			viewY: 9.964599609375
# 			callout: TSpawn
# 			average_damage_per_round: 75.69565217391305
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 0
#
# 		dead_players:
# 	winningSide: T
# round:9
# 	round_winner: T
# 	round_number: 9
# 	bomb_coordinates: [993.7843627929688, 2552.73876953125, 95.9132080078125]
# 	round_length: 15948
# 	bomb_plant_time: 138069
# 	ct_team
# 		rounds_won: 4
# 		team_equipment_value: 27000
# 		living_players:
# 			playerName: NAF
# 			is_alive: True
# 			hp: 100
# 			armor: 100
# 			equipment_value: 4500
# 			cash_spend_this_round: 1400
# 			primary_weapon: M4A1
# 			secondary_weapon: USP-S
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 1
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 1900
# 			has_helmet: False
# 			has_defuser: False
# 			total_kills: 16
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 16
# 			headshot_percentage: 0
# 			lastKnownPosition: [-1366.00390625, 2553.07373046875, 115.22265625]
# 			velocityX: -0.18776747584342957
# 			velocityY: -74.60345458984375
# 			velocityZ: -78.125
# 			viewX: 270.1702880859375
# 			viewY: 15.9686279296875
# 			callout: BombsiteB
# 			average_damage_per_round: 78.26086956521739
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 19
#
# 			playerName: Grim
# 			is_alive: True
# 			hp: 39
# 			armor: 91
# 			equipment_value: 4500
# 			cash_spend_this_round: 1400
# 			primary_weapon: AK-47
# 			secondary_weapon: USP-S
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 1
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 4400
# 			has_helmet: True
# 			has_defuser: True
# 			total_kills: 6
# 			round_kills: 1
# 			round_deaths: 0
# 			total_deaths: 16
# 			headshot_percentage: 0
# 			lastKnownPosition: [-1559.3330078125, 982.0000610351562, 36.341697692871094]
# 			velocityX: 0
# 			velocityY: 0
# 			velocityZ: 0
# 			viewX: 88.8739013671875
# 			viewY: 1.0491943359375
# 			callout: UpperTunnel
# 			average_damage_per_round: 38.130434782608695
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 108
#
# 			playerName: Stewie2K
# 			is_alive: True
# 			hp: 19
# 			armor: 98
# 			equipment_value: 6600
# 			cash_spend_this_round: 1200
# 			primary_weapon: AWP
# 			secondary_weapon: USP-S
# 			active_weapon_category: Knife
# 			grenades_left: 0
# 			flashes_left: 2
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 5200
# 			has_helmet: False
# 			has_defuser: False
# 			total_kills: 8
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 17
# 			headshot_percentage: 0
# 			lastKnownPosition: [-1540.2335205078125, 2673.98681640625, 32.8359375]
# 			velocityX: -93.26764678955078
# 			velocityY: 182.0377655029297
# 			velocityZ: -346.875
# 			viewX: 350.562744140625
# 			viewY: 9.7998046875
# 			callout: BombsiteB
# 			average_damage_per_round: 53.608695652173914
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 0
#
# 		dead_players:
# 			playerName: FalleN
# 			equipment_value: 6350
# 			cash_spend_this_round: 3400
# 			cash: 1900
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [549.6451416015625, 2283.984130859375, 127.03125]
# 			callout: Failed
# 			time_of_death: 135094
# 			person_killed_by: Boombl4
# 			weapon_killed_by: AK-47
# 			amount_spent: 21500
# 			round_damage: 84
#
# 			playerName: EliGE
# 			equipment_value: 5050
# 			cash_spend_this_round: 4850
# 			cash: 2000
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [1139.0992431640625, 2653.419921875, 94.87654876708984]
# 			callout: BombsiteA
# 			time_of_death: 135529
# 			person_killed_by: b1t
# 			weapon_killed_by: AK-47
# 			amount_spent: 23500
# 			round_damage: 11
#
# 	t_team
# 		rounds_won: 4
# 		team_equipment_value: 24550
# 		living_players:
# 			playerName: s1mple
# 			is_alive: True
# 			hp: 81
# 			armor: 98
# 			equipment_value: 3900
# 			cash_spend_this_round: 1100
# 			primary_weapon: AK-47
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 6300
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 14
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 13
# 			headshot_percentage: 0
# 			lastKnownPosition: [1661.9525146484375, 458.94622802734375, 55.38846206665039]
# 			velocityX: 129.55557250976562
# 			velocityY: -97.9889144897461
# 			velocityZ: 0
# 			viewX: 70.6640625
# 			viewY: 7.8607177734375
# 			callout: Side
# 			average_damage_per_round: 84.91304347826087
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 81
#
# 			playerName: Boombl4
# 			is_alive: True
# 			hp: 16
# 			armor: 95
# 			equipment_value: 5950
# 			cash_spend_this_round: 1100
# 			primary_weapon: AWP
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: True
# 			is_scoped: True
# 			cash: 6300
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 17
# 			round_kills: 1
# 			round_deaths: 0
# 			total_deaths: 9
# 			headshot_percentage: 0
# 			lastKnownPosition: [1757.670166015625, 637.2904052734375, 55.08634948730469]
# 			velocityX: 25.665340423583984
# 			velocityY: 15.188215255737305
# 			velocityZ: 0
# 			viewX: 170.70556640625
# 			viewY: 2.8948974609375
# 			callout: Side
# 			average_damage_per_round: 68.8695652173913
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 100
#
# 			playerName: Perfecto
# 			is_alive: True
# 			hp: 95
# 			armor: 97
# 			equipment_value: 4700
# 			cash_spend_this_round: 900
# 			primary_weapon: AK-47
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Knife
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 6950
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 15
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 10
# 			headshot_percentage: 0
# 			lastKnownPosition: [631.2442016601562, 973.850341796875, 42.5345458984375]
# 			velocityX: -161.8814239501953
# 			velocityY: -148.8980255126953
# 			velocityZ: 148.86837768554688
# 			viewX: 271.845703125
# 			viewY: 0.966796875
# 			callout: LongDoors
# 			average_damage_per_round: 69.47826086956522
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 0
#
# 			playerName: b1t
# 			is_alive: True
# 			hp: 81
# 			armor: 80
# 			equipment_value: 5000
# 			cash_spend_this_round: 700
# 			primary_weapon: AK-47
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Secondary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 7000
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 19
# 			round_kills: 1
# 			round_deaths: 0
# 			total_deaths: 9
# 			headshot_percentage: 0
# 			lastKnownPosition: [1348.2978515625, 325.9488220214844, -161.34481811523438]
# 			velocityX: 136.9397735595703
# 			velocityY: -70.00593566894531
# 			velocityZ: 0
# 			viewX: 86.2371826171875
# 			viewY: 16.0235595703125
# 			callout: Pit
# 			average_damage_per_round: 83.56521739130434
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 100
#
# 		dead_players:
# 			playerName: electronic
# 			equipment_value: 5000
# 			cash_spend_this_round: 1100
# 			cash: 6050
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [882.31103515625, 829.2213134765625, 0.9501075744628906]
# 			callout: LongDoors
# 			time_of_death: 136894
# 			person_killed_by: Grim
# 			weapon_killed_by: M4A1
# 			amount_spent: 19850
# 			round_damage: 61
#
# 	winningSide: T
# round:10
# 	round_winner: CT
# 	round_number: 10
# 	bomb_coordinates: [992.5216674804688, 2544.511474609375, 95.9600830078125]
# 	round_length: 21630
# 	bomb_plant_time: 160627
# 	ct_team
# 		rounds_won: 4
# 		team_equipment_value: 28900
# 		living_players:
# 			playerName: Stewie2K
# 			is_alive: True
# 			hp: 72
# 			armor: 94
# 			equipment_value: 6000
# 			cash_spend_this_round: 5050
# 			primary_weapon: AWP
# 			secondary_weapon: USP-S
# 			active_weapon_category: Knife
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 4050
# 			has_helmet: False
# 			has_defuser: True
# 			total_kills: 8
# 			round_kills: 1
# 			round_deaths: 0
# 			total_deaths: 17
# 			headshot_percentage: 0
# 			lastKnownPosition: [941.5142822265625, 2554.81298828125, 95.85015869140625]
# 			velocityX: 0
# 			velocityY: 0
# 			velocityZ: 0
# 			viewX: 359.6044921875
# 			viewY: 40.9185791015625
# 			callout: BombsiteA
# 			average_damage_per_round: 53.608695652173914
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 151
#
# 			playerName: Grim
# 			is_alive: True
# 			hp: 67
# 			armor: 86
# 			equipment_value: 6350
# 			cash_spend_this_round: 4300
# 			primary_weapon: AWP
# 			secondary_weapon: USP-S
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 4200
# 			has_helmet: True
# 			has_defuser: True
# 			total_kills: 6
# 			round_kills: 2
# 			round_deaths: 0
# 			total_deaths: 16
# 			headshot_percentage: 0
# 			lastKnownPosition: [-696.5713500976562, 1418.3782958984375, -68.28778839111328]
# 			velocityX: -244.9126434326172
# 			velocityY: 81.49882507324219
# 			velocityZ: 130.11837768554688
# 			viewX: 168.1842041015625
# 			viewY: 12.6177978515625
# 			callout: LowerTunnel
# 			average_damage_per_round: 38.130434782608695
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 78
#
# 		dead_players:
# 			playerName: FalleN
# 			equipment_value: 6000
# 			cash_spend_this_round: 1650
# 			cash: 3850
# 			round_kills: 1
# 			round_deaths: 1
# 			lastKnownPosition: [1574.1702880859375, 1612.3262939453125, -0.019931793212890625]
# 			callout: LongA
# 			time_of_death: 159925
# 			person_killed_by: Perfecto
# 			weapon_killed_by: AK-47
# 			amount_spent: 23150
# 			round_damage: 161
#
# 			playerName: NAF
# 			equipment_value: 5250
# 			cash_spend_this_round: 1800
# 			cash: 3600
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [-529.6512451171875, 2335.0546875, -110.5647964477539]
# 			callout: MidDoors
# 			time_of_death: 157228
# 			person_killed_by: electronic
# 			weapon_killed_by: AK-47
# 			amount_spent: 26300
# 			round_damage: 0
#
# 			playerName: EliGE
# 			equipment_value: 5300
# 			cash_spend_this_round: 1900
# 			cash: 3900
# 			round_kills: 1
# 			round_deaths: 1
# 			lastKnownPosition: [1238.5682373046875, 3021.322265625, 128.4303436279297]
# 			callout: BombsiteA
# 			time_of_death: 159166
# 			person_killed_by: Boombl4
# 			weapon_killed_by: AK-47
# 			amount_spent: 25400
# 			round_damage: 110
#
# 	t_team
# 		rounds_won: 5
# 		team_equipment_value: 25050
# 		living_players:
# 		dead_players:
# 			playerName: Perfecto
# 			equipment_value: 4300
# 			cash_spend_this_round: 1100
# 			cash: 8650
# 			round_kills: 1
# 			round_deaths: 1
# 			lastKnownPosition: [1178.688232421875, 2720.883056640625, 97.67236328125]
# 			callout: BombsiteA
# 			time_of_death: 161206
# 			person_killed_by: Grim
# 			weapon_killed_by: M4A1
# 			amount_spent: 20350
# 			round_damage: 102
#
# 			playerName: Boombl4
# 			equipment_value: 4300
# 			cash_spend_this_round: 1100
# 			cash: 7700
# 			round_kills: 1
# 			round_deaths: 1
# 			lastKnownPosition: [288.2381896972656, 1853.902587890625, 97.67971801757812]
# 			callout: ShortStairs
# 			time_of_death: 162377
# 			person_killed_by: Grim
# 			weapon_killed_by: M4A1
# 			amount_spent: 21000
# 			round_damage: 107
#
# 			playerName: s1mple
# 			equipment_value: 6450
# 			cash_spend_this_round: 700
# 			cash: 7800
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [-342.7803955078125, 1297.698486328125, -122.48103332519531]
# 			callout: Middle
# 			time_of_death: 156138
# 			person_killed_by: FalleN
# 			weapon_killed_by: AWP
# 			amount_spent: 20000
# 			round_damage: 0
#
# 			playerName: b1t
# 			equipment_value: 5000
# 			cash_spend_this_round: 800
# 			cash: 8400
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [391.58416748046875, 2301.290771484375, 95.84422302246094]
# 			callout: ExtendedA
# 			time_of_death: 157276
# 			person_killed_by: EliGE
# 			weapon_killed_by: AK-47
# 			amount_spent: 20000
# 			round_damage: 52
#
# 			playerName: electronic
# 			equipment_value: 5000
# 			cash_spend_this_round: 4800
# 			cash: 3750
# 			round_kills: 1
# 			round_deaths: 1
# 			lastKnownPosition: [-1945.6983642578125, 1613.382568359375, 33.781333923339844]
# 			callout: UpperTunnel
# 			time_of_death: 158928
# 			person_killed_by: Stewie2K
# 			weapon_killed_by: AWP
# 			amount_spent: 24650
# 			round_damage: 100
#
# 	winningSide: CT
# round:12
# 	round_winner: T
# 	round_number: 12
# 	bomb_coordinates: [1235.96875, 2560.03125, 99.37853240966797]
# 	round_length: 17263
# 	bomb_plant_time: 185505
# 	ct_team
# 		rounds_won: 5
# 		team_equipment_value: 5350
# 		living_players:
# 			playerName: NAF
# 			is_alive: True
# 			hp: 53
# 			armor: 0
# 			equipment_value: 700
# 			cash_spend_this_round: 700
# 			primary_weapon: None
# 			secondary_weapon: Five-SeveN
# 			active_weapon_category: Secondary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 3200
# 			has_helmet: False
# 			has_defuser: False
# 			total_kills: 16
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 16
# 			headshot_percentage: 0
# 			lastKnownPosition: [731.661865234375, 421.7407531738281, 3.3249764442443848]
# 			velocityX: -67.06522369384766
# 			velocityY: 168.9621124267578
# 			velocityZ: 0
# 			viewX: 97.6629638671875
# 			viewY: 1.3787841796875
# 			callout: LongDoors
# 			average_damage_per_round: 78.26086956521739
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 0
#
# 		dead_players:
# 			playerName: FalleN
# 			equipment_value: 400
# 			cash_spend_this_round: 200
# 			cash: 3100
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [1047.3111572265625, 2152.97509765625, 1.9913290739059448]
# 			callout: UnderA
# 			time_of_death: 184604
# 			person_killed_by: Perfecto
# 			weapon_killed_by: AK-47
# 			amount_spent: 27200
# 			round_damage: 0
#
# 			playerName: Grim
# 			equipment_value: 1350
# 			cash_spend_this_round: 1350
# 			cash: 2050
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [1112.9813232421875, 2604.729248046875, 96.4220199584961]
# 			callout: BombsiteA
# 			time_of_death: 183111
# 			person_killed_by: s1mple
# 			weapon_killed_by: AWP
# 			amount_spent: 28450
# 			round_damage: 69
#
# 			playerName: EliGE
# 			equipment_value: 1350
# 			cash_spend_this_round: 1350
# 			cash: 2000
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [659.0518798828125, 2378.17724609375, 124.833984375]
# 			callout: UnderA
# 			time_of_death: 184529
# 			person_killed_by: b1t
# 			weapon_killed_by: AK-47
# 			amount_spent: 30600
# 			round_damage: 0
#
# 			playerName: Stewie2K
# 			equipment_value: 1550
# 			cash_spend_this_round: 1550
# 			cash: 1900
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [1265.55615234375, 2269.967529296875, 12.403157234191895]
# 			callout: LongA
# 			time_of_death: 185843
# 			person_killed_by: s1mple
# 			weapon_killed_by: AWP
# 			amount_spent: 28850
# 			round_damage: 71
#
# 	t_team
# 		rounds_won: 6
# 		team_equipment_value: 25650
# 		living_players:
# 			playerName: b1t
# 			is_alive: True
# 			hp: 87
# 			armor: 90
# 			equipment_value: 4400
# 			cash_spend_this_round: 0
# 			primary_weapon: AK-47
# 			secondary_weapon: Desert Eagle
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 10950
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 19
# 			round_kills: 1
# 			round_deaths: 0
# 			total_deaths: 9
# 			headshot_percentage: 0
# 			lastKnownPosition: [953.7288208007812, 1173.343017578125, 36.03125]
# 			velocityX: 0
# 			velocityY: 0
# 			velocityZ: 0
# 			viewX: 234.90966796875
# 			viewY: 2.96630859375
# 			callout: LongDoors
# 			average_damage_per_round: 83.56521739130434
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 89
#
# 			playerName: s1mple
# 			is_alive: True
# 			hp: 86
# 			armor: 92
# 			equipment_value: 6750
# 			cash_spend_this_round: 300
# 			primary_weapon: AWP
# 			secondary_weapon: Desert Eagle
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 1
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: True
# 			is_scoped: True
# 			cash: 8000
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 14
# 			round_kills: 2
# 			round_deaths: 0
# 			total_deaths: 13
# 			headshot_percentage: 0
# 			lastKnownPosition: [998.5458984375, 1196.5384521484375, 0.5492973327636719]
# 			velocityX: -2.0793895721435547
# 			velocityY: -2.0793895721435547
# 			velocityZ: 0
# 			viewX: 233.6297607421875
# 			viewY: 359.36279296875
# 			callout: LongDoors
# 			average_damage_per_round: 84.91304347826087
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 216
#
# 			playerName: Boombl4
# 			is_alive: True
# 			hp: 76
# 			armor: 87
# 			equipment_value: 5000
# 			cash_spend_this_round: 0
# 			primary_weapon: AK-47
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 8150
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 17
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 9
# 			headshot_percentage: 0
# 			lastKnownPosition: [1546.3177490234375, 1346.135498046875, 1.03125]
# 			velocityX: -13.270953178405762
# 			velocityY: 152.10658264160156
# 			velocityZ: 0
# 			viewX: 214.134521484375
# 			viewY: 359.8406982421875
# 			callout: LongA
# 			average_damage_per_round: 68.8695652173913
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 36
#
# 			playerName: electronic
# 			is_alive: True
# 			hp: 27
# 			armor: 94
# 			equipment_value: 4500
# 			cash_spend_this_round: 1100
# 			primary_weapon: AK-47
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 1
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: True
# 			is_scoped: False
# 			cash: 8200
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 16
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 13
# 			headshot_percentage: 0
# 			lastKnownPosition: [877.6681518554688, 930.6715087890625, 0.25923728942871094]
# 			velocityX: -25.207033157348633
# 			velocityY: 66.57364654541016
# 			velocityZ: 0
# 			viewX: 223.956298828125
# 			viewY: 358.406982421875
# 			callout: LongDoors
# 			average_damage_per_round: 75.69565217391305
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 62
#
# 			playerName: Perfecto
# 			is_alive: True
# 			hp: 29
# 			armor: 98
# 			equipment_value: 5000
# 			cash_spend_this_round: 1100
# 			primary_weapon: AK-47
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 9800
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 15
# 			round_kills: 1
# 			round_deaths: 0
# 			total_deaths: 10
# 			headshot_percentage: 0
# 			lastKnownPosition: [1292.11279296875, 676.65966796875, -28.219242095947266]
# 			velocityX: 9.500890731811523
# 			velocityY: -81.16958618164062
# 			velocityZ: 0
# 			viewX: 167.0361328125
# 			viewY: 357.4676513671875
# 			callout: Pit
# 			average_damage_per_round: 69.47826086956522
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 44
#
# 		dead_players:
# 	winningSide: T
# round:15
# 	round_winner: T
# 	round_number: 15
# 	bomb_coordinates: [982.070068359375, 2530.321044921875, 96.06622314453125]
# 	round_length: 18662
# 	bomb_plant_time: 230996
# 	ct_team
# 		rounds_won: 6
# 		team_equipment_value: 26350
# 		living_players:
# 		dead_players:
# 			playerName: Grim
# 			equipment_value: 5600
# 			cash_spend_this_round: 1450
# 			cash: 4000
# 			round_kills: 1
# 			round_deaths: 1
# 			lastKnownPosition: [1301.0618896484375, 2535.10595703125, 72.89695739746094]
# 			callout: ARamp
# 			time_of_death: 229850
# 			person_killed_by: b1t
# 			weapon_killed_by: AK-47
# 			amount_spent: 34350
# 			round_damage: 152
#
# 			playerName: EliGE
# 			equipment_value: 4150
# 			cash_spend_this_round: 3600
# 			cash: 2300
# 			round_kills: 1
# 			round_deaths: 1
# 			lastKnownPosition: [1169.896728515625, 2773.662841796875, 117.33011627197266]
# 			callout: BombsiteA
# 			time_of_death: 233528
# 			person_killed_by: s1mple
# 			weapon_killed_by: AWP
# 			amount_spent: 38450
# 			round_damage: 115
#
# 			playerName: Stewie2K
# 			equipment_value: 4600
# 			cash_spend_this_round: 1800
# 			cash: 3700
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [5.785523414611816, 1400.4271240234375, -0.2868216037750244]
# 			callout: Catwalk
# 			time_of_death: 231232
# 			person_killed_by: s1mple
# 			weapon_killed_by: AWP
# 			amount_spent: 34900
# 			round_damage: 0
#
# 			playerName: FalleN
# 			equipment_value: 6650
# 			cash_spend_this_round: 3100
# 			cash: 2450
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [-537.7310180664062, 2119.933837890625, -121.1041030883789]
# 			callout: MidDoors
# 			time_of_death: 226782
# 			person_killed_by: s1mple
# 			weapon_killed_by: AWP
# 			amount_spent: 35700
# 			round_damage: 0
#
# 			playerName: NAF
# 			equipment_value: 5350
# 			cash_spend_this_round: 3300
# 			cash: 2000
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [-1068.1177978515625, 1308.1087646484375, -111.80459594726562]
# 			callout: TunnelStairs
# 			time_of_death: 226495
# 			person_killed_by: Perfecto
# 			weapon_killed_by: AK-47
# 			amount_spent: 38750
# 			round_damage: 25
#
# 	t_team
# 		rounds_won: 8
# 		team_equipment_value: 27650
# 		living_players:
# 			playerName: s1mple
# 			is_alive: True
# 			hp: 100
# 			armor: 100
# 			equipment_value: 7550
# 			cash_spend_this_round: 10250
# 			primary_weapon: AWP
# 			secondary_weapon: Desert Eagle
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 4800
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 14
# 			round_kills: 3
# 			round_deaths: 0
# 			total_deaths: 13
# 			headshot_percentage: 0
# 			lastKnownPosition: [455.1625061035156, 2008.0943603515625, 133.03125]
# 			velocityX: 8.942205429077148
# 			velocityY: -8.968603134155273
# 			velocityZ: 0
# 			viewX: 46.4776611328125
# 			viewY: 1.73583984375
# 			callout:
# 			average_damage_per_round: 84.91304347826087
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 274
#
# 			playerName: Perfecto
# 			is_alive: True
# 			hp: 75
# 			armor: 94
# 			equipment_value: 5100
# 			cash_spend_this_round: 5300
# 			primary_weapon: AK-47
# 			secondary_weapon: Tec-9
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 11400
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 15
# 			round_kills: 1
# 			round_deaths: 0
# 			total_deaths: 10
# 			headshot_percentage: 0
# 			lastKnownPosition: [563.9917602539062, 2744.852294921875, 96.88147735595703]
# 			velocityX: 0
# 			velocityY: 0
# 			velocityZ: 0
# 			viewX: 347.2064208984375
# 			viewY: 1.95556640625
# 			callout: ExtendedA
# 			average_damage_per_round: 69.47826086956522
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 100
#
# 			playerName: b1t
# 			is_alive: True
# 			hp: 33
# 			armor: 84
# 			equipment_value: 4400
# 			cash_spend_this_round: 4800
# 			primary_weapon: AK-47
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 13650
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 19
# 			round_kills: 1
# 			round_deaths: 0
# 			total_deaths: 9
# 			headshot_percentage: 0
# 			lastKnownPosition: [379.6921691894531, 1776.9208984375, 103.03125]
# 			velocityX: -70.29014587402344
# 			velocityY: -107.87958526611328
# 			velocityZ: 0
# 			viewX: 53.94287109375
# 			viewY: 6.74560546875
# 			callout: ShortStairs
# 			average_damage_per_round: 83.56521739130434
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 92
#
# 		dead_players:
# 			playerName: Boombl4
# 			equipment_value: 5300
# 			cash_spend_this_round: 5300
# 			cash: 10550
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [436.88323974609375, 2702.055419921875, 160.45652770996094]
# 			callout: ExtendedA
# 			time_of_death: 229448
# 			person_killed_by: Grim
# 			weapon_killed_by: M4A1
# 			amount_spent: 34300
# 			round_damage: 8
#
# 			playerName: electronic
# 			equipment_value: 5300
# 			cash_spend_this_round: 5300
# 			cash: 9500
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [-100.6328125, 1580.173828125, 2.3271865844726562]
# 			callout: Failed
# 			time_of_death: 230136
# 			person_killed_by: EliGE
# 			weapon_killed_by: M4A1
# 			amount_spent: 34450
# 			round_damage: 26
#
# 	winningSide: T
# round:16
# 	round_winner: CT
# 	round_number: 16
# 	bomb_coordinates: [-1435.4415283203125, 2676.157958984375, 16.086488723754883]
# 	round_length: 41122
# 	bomb_plant_time: 273036
# 	ct_team
# 		rounds_won: 6
# 		team_equipment_value: 4500
# 		living_players:
# 			playerName: b1t
# 			is_alive: True
# 			hp: 81
# 			armor: 94
# 			equipment_value: 900
# 			cash_spend_this_round: 650
# 			primary_weapon: None
# 			secondary_weapon: USP-S
# 			active_weapon_category: Knife
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 4550
# 			has_helmet: False
# 			has_defuser: False
# 			total_kills: 19
# 			round_kills: 2
# 			round_deaths: 0
# 			total_deaths: 9
# 			headshot_percentage: 0
# 			lastKnownPosition: [-1496.3740234375, 2682.21044921875, 8.816810607910156]
# 			velocityX: 0
# 			velocityY: 0
# 			velocityZ: 0
# 			viewX: 358.9508056640625
# 			viewY: 34.1729736328125
# 			callout: BombsiteB
# 			average_damage_per_round: 83.56521739130434
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 57
#
# 		dead_players:
# 			playerName: s1mple
# 			equipment_value: 850
# 			cash_spend_this_round: 650
# 			cash: 3650
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [-356.7193603515625, 2185.67041015625, -126.18475341796875]
# 			callout: MidDoors
# 			time_of_death: 264701
# 			person_killed_by: EliGE
# 			weapon_killed_by: Glock-18
# 			amount_spent: 39100
# 			round_damage: 0
#
# 			playerName: Boombl4
# 			equipment_value: 1000
# 			cash_spend_this_round: 800
# 			cash: 3800
# 			round_kills: 1
# 			round_deaths: 1
# 			lastKnownPosition: [289.3019104003906, 2358.307861328125, -120.11585998535156]
# 			callout: ExtendedA
# 			time_of_death: 271200
# 			person_killed_by: Stewie2K
# 			weapon_killed_by: P250
# 			amount_spent: 35100
# 			round_damage: 194
#
# 			playerName: Perfecto
# 			equipment_value: 900
# 			cash_spend_this_round: 700
# 			cash: 3600
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [-1382.1243896484375, 2588.549560546875, 119.03125]
# 			callout: Failed
# 			time_of_death: 271637
# 			person_killed_by: NAF
# 			weapon_killed_by: Glock-18
# 			amount_spent: 33550
# 			round_damage: 78
#
# 			playerName: electronic
# 			equipment_value: 850
# 			cash_spend_this_round: 650
# 			cash: 4250
# 			round_kills: 2
# 			round_deaths: 1
# 			lastKnownPosition: [-1824.7919921875, 2496.636962890625, 31.417835235595703]
# 			callout: BombsiteB
# 			time_of_death: 272192
# 			person_killed_by: NAF
# 			weapon_killed_by: Glock-18
# 			amount_spent: 35100
# 			round_damage: 171
#
# 	t_team
# 		rounds_won: 9
# 		team_equipment_value: 4100
# 		living_players:
# 		dead_players:
# 			playerName: FalleN
# 			equipment_value: 900
# 			cash_spend_this_round: 700
# 			cash: 2800
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [-1364.2423095703125, 2144.793701171875, 1.9024276733398438]
# 			callout:
# 			time_of_death: 271607
# 			person_killed_by: electronic
# 			weapon_killed_by: USP-S
# 			amount_spent: 36400
# 			round_damage: 22
#
# 			playerName: Grim
# 			equipment_value: 1150
# 			cash_spend_this_round: 650
# 			cash: 2850
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [-445.68267822265625, 1670.2220458984375, -125.31034851074219]
# 			callout: MidDoors
# 			time_of_death: 263915
# 			person_killed_by: Boombl4
# 			weapon_killed_by: P2000
# 			amount_spent: 35000
# 			round_damage: 0
#
# 			playerName: NAF
# 			equipment_value: 200
# 			cash_spend_this_round: 800
# 			cash: 3300
# 			round_kills: 2
# 			round_deaths: 1
# 			lastKnownPosition: [-1880.8743896484375, 2480.276123046875, 28.818540573120117]
# 			callout: BombsiteB
# 			time_of_death: 273162
# 			person_killed_by: b1t
# 			weapon_killed_by: USP-S
# 			amount_spent: 39550
# 			round_damage: 144
#
# 			playerName: EliGE
# 			equipment_value: 850
# 			cash_spend_this_round: 650
# 			cash: 3150
# 			round_kills: 1
# 			round_deaths: 1
# 			lastKnownPosition: [-1411.9051513671875, 2537.282470703125, 3.0206940174102783]
# 			callout: BombsiteB
# 			time_of_death: 271873
# 			person_killed_by: electronic
# 			weapon_killed_by: USP-S
# 			amount_spent: 39100
# 			round_damage: 100
#
# 			playerName: Stewie2K
# 			equipment_value: 1000
# 			cash_spend_this_round: 700
# 			cash: 3400
# 			round_kills: 1
# 			round_deaths: 1
# 			lastKnownPosition: [-1553.6336669921875, 2601.888671875, 4.696388244628906]
# 			callout: BombsiteB
# 			time_of_death: 273800
# 			person_killed_by: b1t
# 			weapon_killed_by: USP-S
# 			amount_spent: 35600
# 			round_damage: 153
#
# 	winningSide: CT
# round:19
# 	round_winner: CT
# 	round_number: 19
# 	bomb_coordinates: [-1684.001953125, 2551.65625, 7.039588928222656]
# 	round_length: 18040
# 	bomb_plant_time: 320950
# 	ct_team
# 		rounds_won: 9
# 		team_equipment_value: 25450
# 		living_players:
# 			playerName: s1mple
# 			is_alive: True
# 			hp: 39
# 			armor: 88
# 			equipment_value: 6950
# 			cash_spend_this_round: 2000
# 			primary_weapon: AWP
# 			secondary_weapon: P2000
# 			active_weapon_category: Knife
# 			grenades_left: 0
# 			flashes_left: 1
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 7000
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 14
# 			round_kills: 1
# 			round_deaths: 0
# 			total_deaths: 13
# 			headshot_percentage: 0
# 			lastKnownPosition: [-1696.407470703125, 2491.21533203125, 10.508051872253418]
# 			velocityX: 0
# 			velocityY: 0
# 			velocityZ: 0
# 			viewX: 79.4256591796875
# 			viewY: 28.6248779296875
# 			callout: BombsiteB
# 			average_damage_per_round: 84.91304347826087
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 100
#
# 			playerName: electronic
# 			is_alive: True
# 			hp: 100
# 			armor: 88
# 			equipment_value: 4100
# 			cash_spend_this_round: 1100
# 			primary_weapon: AK-47
# 			secondary_weapon: USP-S
# 			active_weapon_category: Knife
# 			grenades_left: 0
# 			flashes_left: 1
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 7750
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 16
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 13
# 			headshot_percentage: 0
# 			lastKnownPosition: [-465.3375549316406, 1935.791748046875, -124.34174346923828]
# 			velocityX: -1.9728336334228516
# 			velocityY: -234.48497009277344
# 			velocityZ: 0
# 			viewX: 280.8380126953125
# 			viewY: 9.1845703125
# 			callout: MidDoors
# 			average_damage_per_round: 75.69565217391305
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 0
#
# 			playerName: Boombl4
# 			is_alive: True
# 			hp: 73
# 			armor: 96
# 			equipment_value: 4100
# 			cash_spend_this_round: 1400
# 			primary_weapon: AK-47
# 			secondary_weapon: P2000
# 			active_weapon_category: Knife
# 			grenades_left: 0
# 			flashes_left: 1
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 6850
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 17
# 			round_kills: 2
# 			round_deaths: 0
# 			total_deaths: 9
# 			headshot_percentage: 0
# 			lastKnownPosition: [234.19952392578125, 2156.7158203125, -127.67884826660156]
# 			velocityX: 249.88853454589844
# 			velocityY: 7.464394569396973
# 			velocityZ: 0
# 			viewX: 1.7083740234375
# 			viewY: 10.2392578125
# 			callout: CTSpawn
# 			average_damage_per_round: 68.8695652173913
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 122
#
# 		dead_players:
# 			playerName: Perfecto
# 			equipment_value: 4600
# 			cash_spend_this_round: 5950
# 			cash: 5850
# 			round_kills: 1
# 			round_deaths: 1
# 			lastKnownPosition: [-836.9874877929688, 2162.36083984375, -99.38035583496094]
# 			callout: BDoors
# 			time_of_death: 320158
# 			person_killed_by: NAF
# 			weapon_killed_by: AK-47
# 			amount_spent: 43700
# 			round_damage: 178
#
# 			playerName: b1t
# 			equipment_value: 5700
# 			cash_spend_this_round: 1400
# 			cash: 8100
# 			round_kills: 1
# 			round_deaths: 1
# 			lastKnownPosition: [-1160.468505859375, 2106.130126953125, 41.03125]
# 			callout: Failed
# 			time_of_death: 319582
# 			person_killed_by: FalleN
# 			weapon_killed_by: AWP
# 			amount_spent: 38900
# 			round_damage: 100
#
# 	t_team
# 		rounds_won: 9
# 		team_equipment_value: 24550
# 		living_players:
# 		dead_players:
# 			playerName: Grim
# 			equipment_value: 4450
# 			cash_spend_this_round: 4250
# 			cash: 4550
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [-1918.9532470703125, 2403.400390625, 11.055072784423828]
# 			callout: BombsiteB
# 			time_of_death: 323555
# 			person_killed_by: Boombl4
# 			weapon_killed_by: M4A1
# 			amount_spent: 43400
# 			round_damage: 27
#
# 			playerName: EliGE
# 			equipment_value: 4900
# 			cash_spend_this_round: 4700
# 			cash: 4250
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [-569.6568603515625, 2105.793701171875, -118.666259765625]
# 			callout: MidDoors
# 			time_of_death: 319516
# 			person_killed_by: b1t
# 			weapon_killed_by: AK-47
# 			amount_spent: 47500
# 			round_damage: 0
#
# 			playerName: NAF
# 			equipment_value: 5000
# 			cash_spend_this_round: 4800
# 			cash: 4550
# 			round_kills: 1
# 			round_deaths: 1
# 			lastKnownPosition: [-330.08135986328125, 2123.732177734375, -127.97164916992188]
# 			callout: MidDoors
# 			time_of_death: 320394
# 			person_killed_by: Boombl4
# 			weapon_killed_by: M4A1
# 			amount_spent: 48400
# 			round_damage: 100
#
# 			playerName: Stewie2K
# 			equipment_value: 4600
# 			cash_spend_this_round: 4400
# 			cash: 4300
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [302.6598815917969, 1678.1488037109375, 43.20526885986328]
# 			callout: ShortStairs
# 			time_of_death: 316982
# 			person_killed_by: s1mple
# 			weapon_killed_by: AWP
# 			amount_spent: 44500
# 			round_damage: 61
#
# 			playerName: FalleN
# 			equipment_value: 5600
# 			cash_spend_this_round: 5400
# 			cash: 4300
# 			round_kills: 1
# 			round_deaths: 1
# 			lastKnownPosition: [-345.15911865234375, 1987.0430908203125, -126.35350036621094]
# 			callout: MidDoors
# 			time_of_death: 319766
# 			person_killed_by: Perfecto
# 			weapon_killed_by: MP7
# 			amount_spent: 44500
# 			round_damage: 100
#
# 	winningSide: CT
# round:20
# 	round_winner: T
# 	round_number: 20
# 	bomb_coordinates: [1089.6181640625, 2492.927734375, 96.03125]
# 	round_length: 15009
# 	bomb_plant_time: 335118
# 	ct_team
# 		rounds_won: 10
# 		team_equipment_value: 30900
# 		living_players:
# 			playerName: Perfecto
# 			is_alive: True
# 			hp: 100
# 			armor: 100
# 			equipment_value: 5700
# 			cash_spend_this_round: 2800
# 			primary_weapon: AK-47
# 			secondary_weapon: USP-S
# 			active_weapon_category: Knife
# 			grenades_left: 1
# 			flashes_left: 1
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 4450
# 			has_helmet: True
# 			has_defuser: True
# 			total_kills: 15
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 10
# 			headshot_percentage: 0
# 			lastKnownPosition: [-1413.7578125, 2218.240478515625, 0.03125]
# 			velocityX: 4.096311092376709
# 			velocityY: 208.42404174804688
# 			velocityZ: 0
# 			viewX: 358.87939453125
# 			viewY: 7.1630859375
# 			callout: BombsiteB
# 			average_damage_per_round: 69.47826086956522
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 0
#
# 			playerName: electronic
# 			is_alive: True
# 			hp: 100
# 			armor: 88
# 			equipment_value: 5400
# 			cash_spend_this_round: 1600
# 			primary_weapon: AK-47
# 			secondary_weapon: USP-S
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 1
# 			smokes_left: 1
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 7850
# 			has_helmet: True
# 			has_defuser: True
# 			total_kills: 16
# 			round_kills: 1
# 			round_deaths: 0
# 			total_deaths: 13
# 			headshot_percentage: 0
# 			lastKnownPosition: [-1690.5703125, 1814.47900390625, 2.1386566162109375]
# 			velocityX: 2.9755983352661133
# 			velocityY: -5.368897914886475
# 			velocityZ: 0
# 			viewX: 42.2479248046875
# 			viewY: 0.5767822265625
# 			callout: BombsiteB
# 			average_damage_per_round: 75.69565217391305
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 73
#
# 			playerName: Boombl4
# 			is_alive: True
# 			hp: 100
# 			armor: 96
# 			equipment_value: 6850
# 			cash_spend_this_round: 4100
# 			primary_weapon: AWP
# 			secondary_weapon: P2000
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 1
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 4150
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 17
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 9
# 			headshot_percentage: 0
# 			lastKnownPosition: [-1899.8343505859375, 1814.0003662109375, 30.069169998168945]
# 			velocityX: 158.82159423828125
# 			velocityY: 0
# 			velocityZ: 0
# 			viewX: 269.560546875
# 			viewY: 1.593017578125
# 			callout: BombsiteB
# 			average_damage_per_round: 68.8695652173913
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 0
#
# 		dead_players:
# 			playerName: b1t
# 			equipment_value: 5700
# 			cash_spend_this_round: 5500
# 			cash: 4000
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [-362.38629150390625, 1581.608642578125, -126.67660522460938]
# 			callout: MidDoors
# 			time_of_death: 333941
# 			person_killed_by: Grim
# 			weapon_killed_by: AK-47
# 			amount_spent: 44400
# 			round_damage: 32
#
# 			playerName: s1mple
# 			equipment_value: 7250
# 			cash_spend_this_round: 1100
# 			cash: 7300
# 			round_kills: 0
# 			round_deaths: 1
# 			lastKnownPosition: [463.33428955078125, 1664.4739990234375, 34.75077438354492]
# 			callout: ShortStairs
# 			time_of_death: 330298
# 			person_killed_by: FalleN
# 			weapon_killed_by: Galil AR
# 			amount_spent: 47250
# 			round_damage: 0
#
# 	t_team
# 		rounds_won: 9
# 		team_equipment_value: 21700
# 		living_players:
# 			playerName: Stewie2K
# 			is_alive: True
# 			hp: 100
# 			armor: 100
# 			equipment_value: 4600
# 			cash_spend_this_round: 4200
# 			primary_weapon: AK-47
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Knife
# 			grenades_left: 0
# 			flashes_left: 1
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 3600
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 8
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 17
# 			headshot_percentage: 0
# 			lastKnownPosition: [1543.3797607421875, 233.60012817382812, -177.18136596679688]
# 			velocityX: 24.362873077392578
# 			velocityY: -248.81005859375
# 			velocityZ: 0
# 			viewX: 275.284423828125
# 			viewY: 15.88623046875
# 			callout: Pit
# 			average_damage_per_round: 53.608695652173914
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 0
#
# 			playerName: FalleN
# 			is_alive: True
# 			hp: 85
# 			armor: 92
# 			equipment_value: 3500
# 			cash_spend_this_round: 4200
# 			primary_weapon: Galil AR
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 1
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 3900
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 8
# 			round_kills: 1
# 			round_deaths: 0
# 			total_deaths: 15
# 			headshot_percentage: 0
# 			lastKnownPosition: [739.681396484375, 1070.991943359375, 0.5718231201171875]
# 			velocityX: 0
# 			velocityY: 0
# 			velocityZ: 0
# 			viewX: 255.05859375
# 			viewY: 0.4339599609375
# 			callout: LongDoors
# 			average_damage_per_round: 37.47826086956522
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 100
#
# 			playerName: EliGE
# 			is_alive: True
# 			hp: 100
# 			armor: 100
# 			equipment_value: 4400
# 			cash_spend_this_round: 4200
# 			primary_weapon: AK-47
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Knife
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 3850
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 17
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 18
# 			headshot_percentage: 0
# 			lastKnownPosition: [1300.1395263671875, 331.1188659667969, -154.5247802734375]
# 			velocityX: 5.5410943031311035
# 			velocityY: 129.88185119628906
# 			velocityZ: 0
# 			viewX: 87.5555419921875
# 			viewY: 2.43896484375
# 			callout: Pit
# 			average_damage_per_round: 92.43478260869566
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 0
#
# 			playerName: NAF
# 			is_alive: True
# 			hp: 96
# 			armor: 97
# 			equipment_value: 4600
# 			cash_spend_this_round: 4400
# 			primary_weapon: AK-47
# 			secondary_weapon: Glock-18
# 			active_weapon_category: Primary
# 			grenades_left: 0
# 			flashes_left: 0
# 			smokes_left: 0
# 			molotovs_left: 0
# 			is_blinded: False
# 			is_ducking: False
# 			is_scoped: False
# 			cash: 3650
# 			has_helmet: True
# 			has_defuser: False
# 			total_kills: 16
# 			round_kills: 0
# 			round_deaths: 0
# 			total_deaths: 16
# 			headshot_percentage: 0
# 			lastKnownPosition: [1768.8126220703125, 1007.9943237304688, 63.66926956176758]
# 			velocityX: 0
# 			velocityY: 0
# 			velocityZ: 0
# 			viewX: 192.0684814453125
# 			viewY: 3.065185546875
# 			callout: Failed
# 			average_damage_per_round: 78.26086956521739
# 			survives_round: True
# 			time_of_death: 0
# 			round_damage: 0
#
# 		dead_players:
# 			playerName: Grim
# 			equipment_value: 4600
# 			cash_spend_this_round: 4400
# 			cash: 3950
# 			round_kills: 1
# 			round_deaths: 1
# 			lastKnownPosition: [-401.66900634765625, 1572.8311767578125, -126.2301025390625]
# 			callout: MidDoors
# 			time_of_death: 334145
# 			person_killed_by: electronic
# 			weapon_killed_by: AK-47
# 			amount_spent: 47800
# 			round_damage: 100
#
# 	winningSide: T

# %%
print(stat.keys())

def timestamp(parsed_data, roundnum):
    plant_tick=[]
    site=""
    for bomb_event in parsed_data["gameRounds"][roundnum]["bombEvents"]:
        if bomb_event["bombAction"]=="plant":
            plant_tick.append(bomb_event["tick"])
            plant_tick.append(bomb_event["bombSite"])

    return plant_tick

def getPrompt(demo_data, roundNum, total):
    bombTick=timestamp(demo_data, roundNum-1)[0]
    bombSite=timestamp(demo_data, roundNum-1)[1]
    print(bombTick)
    tlive, tdead, textra=get_players(demo_data, roundNum, bombTick, "tSide")
    ctlive, ctdead, ctextra=get_players(demo_data, roundNum, bombTick, "ctSide")

    t={}
    ct={}

    for ID, player in tlive.items():
        tlive[ID]["total_kills"]=total[1][ID]
        tlive[ID]["total_deaths"]=total[0][ID]
        tlive[ID]["average_damage_per_round"]=total[2][ID]
    for ID, player in tdead.items():
        tdead[ID]["total_kills"]=total[1][ID]
        tdead[ID]["total_deaths"]=total[0][ID]
        tdead[ID]["average_damage_per_round"]=total[2][ID]
    for ID, player in ctlive.items():
        ctlive[ID]["total_kills"]=total[1][ID]
        ctlive[ID]["total_deaths"]=total[0][ID]
        ctlive[ID]["average_damage_per_round"]=total[2][ID]
    for ID, player in ctdead.items():
        ctdead[ID]["total_kills"]=total[1][ID]
        ctdead[ID]["total_deaths"]=total[0][ID]
        ctdead[ID]["average_damage_per_round"]=total[2][ID]
    
    statHolder=[]
    for id, stat in ctlive.items():
        statHolder.append(stat)
    ct["living_players"]=statHolder
    statHolder=[]
    for id, stat in ctdead.items():
        statHolder.append(stat)
    # print(statHolder)
    ct["dead_players"]=statHolder
    statHolder=[]
    for id, stat in tlive.items():
        statHolder.append(stat)
    t["living_players"]=statHolder
    statHolder=[]
    for id, stat in tdead.items():
        statHolder.append(stat)
    t["dead_players"]=statHolder

    # print(t)
    ctTeam="Living_players"
    line=""
    for player in ct["living_players"]:
        for para, value in player.items():
            line=str(para)+": "+str(value)
            ctTeam += "\n\t"+line
        ctTeam+="\n"
    ctTeam+="Dead_players"
    # print(ct["dead_players"])
    for player in ct["dead_players"]:
        for para, value in player.items():
            line=str(para)+": "+str(value)
            ctTeam += "\n\t"+line
        ctTeam+="\n"
    # print(ctTeam)

    tTeam="Living_players"
    line=""
    for player in t["living_players"]:
        for para, value in player.items():
            line=str(para)+": "+str(value)
            tTeam += "\n\t"+line
        tTeam+="\n"
    tTeam+="Dead_players"
    # print(ct["dead_players"])
    for player in t["dead_players"]:
        for para, value in player.items():
            line=str(para)+": "+str(value)
            tTeam += "\n\t"+line
        tTeam+="\n"
    # print(tTeam)

    prompt=f'We are trying to predict who will win this round in CSGO. The bomb has just been planted on Bomb Site {bombSite}.Think step by step about which team is more likely to win the round. Then, tell me which team has a higher chance to win the round.Here is some data you could use to inform your response:\n"""Map: DUST 2  \nBomb Position: {bombSite} \nT-team: {tTeam} \nCT-Team: {ctTeam}'
    return prompt

print(getPrompt(parsed_data,20, total))
# Out:
# dict_keys([1, 5, 8, 9, 10, 12, 15, 16, 19, 20])
# 335118
# We are trying to predict who will win this round in CSGO. The bomb has just been planted on Bomb Site A.Think step by step about which team is more likely to win the round. Then, tell me which team has a higher chance to win the round.Here is some data you could use to inform your response:
# """Map: DUST 2
# Bomb Position: A
# T-team: Living_players
# 	playerName: Stewie2K
# 	is_alive: True
# 	hp: 100
# 	armor: 100
# 	equipment_value: 4600
# 	cash_spend_this_round: 4200
# 	primary_weapon: AK-47
# 	secondary_weapon: Glock-18
# 	active_weapon_category: Primary
# 	grenades_left: 0
# 	flashes_left: 1
# 	smokes_left: 0
# 	molotovs_left: 0
# 	is_blinded: False
# 	is_ducking: True
# 	is_scoped: False
# 	cash: 100
# 	has_helmet: True
# 	has_defuser: False
# 	total_kills: 8
# 	round_kills: 0
# 	round_deaths: 0
# 	total_deaths: 17
# 	headshot_percentage: 0
# 	lastKnownPosition: [1456.433837890625, 2455.17333984375, 35.999267578125]
# 	velocityX: 64.14771270751953
# 	velocityY: 20.293926239013672
# 	velocityZ: 0
# 	viewX: 214.7991943359375
# 	viewY: 1.0052490234375
# 	callout: ARamp
# 	average_damage_per_round: 53.608695652173914
# 	survives_round: True
# 	time_of_death: 0
# 	round_damage: 0
#
# 	playerName: FalleN
# 	is_alive: True
# 	hp: 95
# 	armor: 98
# 	equipment_value: 3500
# 	cash_spend_this_round: 4200
# 	primary_weapon: Galil AR
# 	secondary_weapon: Glock-18
# 	active_weapon_category: Primary
# 	grenades_left: 0
# 	flashes_left: 0
# 	smokes_left: 1
# 	molotovs_left: 0
# 	is_blinded: False
# 	is_ducking: False
# 	is_scoped: False
# 	cash: 400
# 	has_helmet: True
# 	has_defuser: False
# 	total_kills: 8
# 	round_kills: 1
# 	round_deaths: 0
# 	total_deaths: 15
# 	headshot_percentage: 0
# 	lastKnownPosition: [1071.6533203125, 1158.972412109375, 0.07512662559747696]
# 	velocityX: -108.45265197753906
# 	velocityY: -26.506160736083984
# 	velocityZ: 0
# 	viewX: 225.8734130859375
# 	viewY: 0.52734375
# 	callout: LongDoors
# 	average_damage_per_round: 37.47826086956522
# 	survives_round: True
# 	time_of_death: 0
# 	round_damage: 100
#
# 	playerName: EliGE
# 	is_alive: True
# 	hp: 100
# 	armor: 100
# 	equipment_value: 4400
# 	cash_spend_this_round: 4200
# 	primary_weapon: AK-47
# 	secondary_weapon: Glock-18
# 	active_weapon_category: Primary
# 	grenades_left: 0
# 	flashes_left: 1
# 	smokes_left: 0
# 	molotovs_left: 0
# 	is_blinded: False
# 	is_ducking: True
# 	is_scoped: False
# 	cash: 350
# 	has_helmet: True
# 	has_defuser: False
# 	total_kills: 17
# 	round_kills: 0
# 	round_deaths: 0
# 	total_deaths: 18
# 	headshot_percentage: 0
# 	lastKnownPosition: [1089.6181640625, 2492.927734375, 96.03125]
# 	velocityX: 0
# 	velocityY: 0
# 	velocityZ: 0
# 	viewX: 283.6834716796875
# 	viewY: 9.195556640625
# 	callout: BombsiteA
# 	average_damage_per_round: 92.43478260869566
# 	survives_round: True
# 	time_of_death: 0
# 	round_damage: 0
#
# 	playerName: NAF
# 	is_alive: True
# 	hp: 100
# 	armor: 100
# 	equipment_value: 4600
# 	cash_spend_this_round: 4400
# 	primary_weapon: AK-47
# 	secondary_weapon: Glock-18
# 	active_weapon_category: Primary
# 	grenades_left: 0
# 	flashes_left: 0
# 	smokes_left: 0
# 	molotovs_left: 0
# 	is_blinded: False
# 	is_ducking: False
# 	is_scoped: False
# 	cash: 150
# 	has_helmet: True
# 	has_defuser: False
# 	total_kills: 16
# 	round_kills: 0
# 	round_deaths: 0
# 	total_deaths: 16
# 	headshot_percentage: 0
# 	lastKnownPosition: [1051.003662109375, 3059.999267578125, 131.16896057128906]
# 	velocityX: 0
# 	velocityY: 0
# 	velocityZ: 0
# 	viewX: 264.6881103515625
# 	viewY: 4.8944091796875
# 	callout: BombsiteA
# 	average_damage_per_round: 78.26086956521739
# 	survives_round: True
# 	time_of_death: 0
# 	round_damage: 0
# Dead_players
# 	playerName: Grim
# 	equipment_value: 4600
# 	cash_spend_this_round: 4400
# 	cash: 450
# 	round_kills: 1
# 	round_deaths: 1
# 	lastKnownPosition: [-401.66900634765625, 1572.8311767578125, -126.2301025390625]
# 	callout: MidDoors
# 	time_of_death: 334145
# 	person_killed_by: electronic
# 	weapon_killed_by: AK-47
# 	amount_spent: 47800
# 	round_damage: 100
# 	total_kills: 6
# 	total_deaths: 16
# 	average_damage_per_round: 38.130434782608695
#
# CT-Team: Living_players
# 	playerName: Perfecto
# 	is_alive: True
# 	hp: 100
# 	armor: 100
# 	equipment_value: 5700
# 	cash_spend_this_round: 2800
# 	primary_weapon: AK-47
# 	secondary_weapon: USP-S
# 	active_weapon_category: Primary
# 	grenades_left: 1
# 	flashes_left: 1
# 	smokes_left: 0
# 	molotovs_left: 0
# 	is_blinded: False
# 	is_ducking: False
# 	is_scoped: False
# 	cash: 3050
# 	has_helmet: True
# 	has_defuser: True
# 	total_kills: 15
# 	round_kills: 0
# 	round_deaths: 0
# 	total_deaths: 10
# 	headshot_percentage: 0
# 	lastKnownPosition: [-337.0029602050781, 2286.614501953125, -116.39450073242188]
# 	velocityX: 0
# 	velocityY: 4.39284086227417
# 	velocityZ: 0
# 	viewX: 184.6142578125
# 	viewY: 355.924072265625
# 	callout: MidDoors
# 	average_damage_per_round: 69.47826086956522
# 	survives_round: True
# 	time_of_death: 0
# 	round_damage: 0
#
# 	playerName: electronic
# 	is_alive: True
# 	hp: 100
# 	armor: 88
# 	equipment_value: 5400
# 	cash_spend_this_round: 1600
# 	primary_weapon: AK-47
# 	secondary_weapon: USP-S
# 	active_weapon_category: Knife
# 	grenades_left: 0
# 	flashes_left: 1
# 	smokes_left: 1
# 	molotovs_left: 0
# 	is_blinded: False
# 	is_ducking: False
# 	is_scoped: False
# 	cash: 6450
# 	has_helmet: True
# 	has_defuser: True
# 	total_kills: 16
# 	round_kills: 1
# 	round_deaths: 0
# 	total_deaths: 13
# 	headshot_percentage: 0
# 	lastKnownPosition: [442.0032043457031, 2108.567138671875, -126.84050750732422]
# 	velocityX: 125.11203002929688
# 	velocityY: 24.03619384765625
# 	velocityZ: 0
# 	viewX: 11.2664794921875
# 	viewY: 352.5018310546875
# 	callout: ExtendedA
# 	average_damage_per_round: 75.69565217391305
# 	survives_round: True
# 	time_of_death: 0
# 	round_damage: 73
#
# 	playerName: Boombl4
# 	is_alive: True
# 	hp: 100
# 	armor: 96
# 	equipment_value: 5300
# 	cash_spend_this_round: 4100
# 	primary_weapon: M4A1
# 	secondary_weapon: P2000
# 	active_weapon_category: Primary
# 	grenades_left: 0
# 	flashes_left: 0
# 	smokes_left: 1
# 	molotovs_left: 0
# 	is_blinded: False
# 	is_ducking: False
# 	is_scoped: False
# 	cash: 2750
# 	has_helmet: True
# 	has_defuser: False
# 	total_kills: 17
# 	round_kills: 0
# 	round_deaths: 0
# 	total_deaths: 9
# 	headshot_percentage: 0
# 	lastKnownPosition: [-188.61538696289062, 641.5983276367188, 2.0207595825195312]
# 	velocityX: -88.01878356933594
# 	velocityY: -65.6396713256836
# 	velocityZ: 0
# 	viewX: 307.3974609375
# 	viewY: 0.63720703125
# 	callout: TopofMid
# 	average_damage_per_round: 68.8695652173913
# 	survives_round: True
# 	time_of_death: 0
# 	round_damage: 0
# Dead_players
# 	playerName: b1t
# 	equipment_value: 5700
# 	cash_spend_this_round: 5500
# 	cash: 2600
# 	round_kills: 0
# 	round_deaths: 1
# 	lastKnownPosition: [-362.38629150390625, 1581.608642578125, -126.67660522460938]
# 	callout: MidDoors
# 	time_of_death: 333941
# 	person_killed_by: Grim
# 	weapon_killed_by: AK-47
# 	amount_spent: 44400
# 	round_damage: 32
# 	total_kills: 19
# 	total_deaths: 9
# 	average_damage_per_round: 83.56521739130434
#
# 	playerName: s1mple
# 	equipment_value: 7250
# 	cash_spend_this_round: 1100
# 	cash: 5900
# 	round_kills: 0
# 	round_deaths: 1
# 	lastKnownPosition: [463.33428955078125, 1664.4739990234375, 34.75077438354492]
# 	callout: ShortStairs
# 	time_of_death: 330298
# 	person_killed_by: FalleN
# 	weapon_killed_by: Galil AR
# 	amount_spent: 47250
# 	round_damage: 0
# 	total_kills: 14
# 	total_deaths: 13
# 	average_damage_per_round: 84.91304347826087
